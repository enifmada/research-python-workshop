# %% [markdown]
# ## Homework 4
#
# Does Figure Friday exist? Probably not until after qbio, but the intention is for you to use at least one figure that you make here as part of Figure Friday.
#
# Have fun! and remember to always **LABEL YOUR AXES** :)

# %% [markdown]
# ### Problem 1 - please ruin a histogram (not safe for Figure Friday)
#
# In lecture 4, I demonstrated how to selectively alter the outlier points of a boxplot. For this problem, I would like you to generate a univariate dataset (for example, draw 1000 samples from a normal distribution), and plot a histogram, like so:

# %%
import numpy as np
import matplotlib.pyplot as plt

#your code here

# %% [markdown]
# Now for the fun part - in at least two ways that directly call objects in the plot, please destroy this histogram. I am going to make everything positive green with a red border and also everything less than zero slant to the left, but you should do something else:
#
# (you will probably need to look at, at the very least, the documentation for plt.hist as a starting point)

# %%
#your code here

# %% [markdown]
# Disgusting!

# %% [markdown]
# ### Problem 2 - learn a new skill (literally Figure Friday)
#
# Choose a plot type or python package that you would like to become more familiar with. Find (or simulate) data that you think suits the skill you are trying to build and make a figure using those data. Be intentional about why you are choosing to represent the data in the way that you are. Is a relplot what you want? A distplot?
#
# Consider using one of seaborn's example datasets (https://github.com/mwaskom/seaborn-data, use sns.load_dataset() to actually use it), but of course you are welcome to use your own dataset, learn a package other than seaborn or matplotlib, etc.
